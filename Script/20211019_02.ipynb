# %%
#2021.10.18. MON
#Team_SmokeFree

## Map Visualization Per GU
#00. 패키지 호출하기. 
import folium
import pandas as pd
import json

#01. 데이터셋 불러오기. 
#(1) 서울특별시 구 geojson 파일 불러오기. 
SEOUL_GU = json.load(open('A:/Python_Project/Team_SmokeFree/Data/00_Raw/skorea_municipalities_geo_simple.json', encoding='utf8'))

#(2) SUBWAY_DATA 데이터셋 불러오기.
SUBWAY_DATA = pd.read_excel('A:/Python_Project/Team_SmokeFree/Data/01_Feature_Data/서울특별시_지하철_pp.xlsx')

#(3) 처리 결과 확인하기. 
SUBWAY_DATA.head()
# Out:
#    자치구      행정동_코드          행정동    역명    호선  \
# 0   중구  1114054000          회현동    서울  01호선
# 1   중구  1114052000          소공동    시청  01호선
# 2  종로구  1111061500  종로1.2.3.4가동    종각  01호선
# 3  종로구  1111061500  종로1.2.3.4가동  종로3가  01호선
# 4  종로구  1111063000      종로5.6가동  종로5가  01호선
#
#                                 소재지_도로명_주소  소재지_지번_주소         위도          경도
# 0      서울특별시 세종대로 지하 2 (남대문로 5가) (1호선 서울역)        NaN  37.554648  126.972559
# 1         서울특별시 세종대로 지하 101 (정동) (1호선 시청역)        NaN  37.564718  126.977108
# 2          서울특별시 종로구 종로 지하 55 (종로1가) (종각역)        NaN  37.570161  126.982923
# 3   서울특별시 종로구 종로 지하 129 (종로3가) (1호선 종로3가역)        NaN  37.571607  126.991806
# 4  서울특별시 종로구 종로 지하 216  (종로5가) (1호선 종로5가역)        NaN  37.570926  127.001849

# %%
#(4) 데이터셋 호선 별로 나누기. 
SUBWAY_DATA_01 = SUBWAY_DATA[SUBWAY_DATA['호선']=='01호선']
SUBWAY_DATA_02 = SUBWAY_DATA[SUBWAY_DATA['호선']=='02호선']
SUBWAY_DATA_03 = SUBWAY_DATA[SUBWAY_DATA['호선']=='03호선']
SUBWAY_DATA_04 = SUBWAY_DATA[SUBWAY_DATA['호선']=='04호선']
SUBWAY_DATA_05 = SUBWAY_DATA[SUBWAY_DATA['호선']=='05호선']
SUBWAY_DATA_06 = SUBWAY_DATA[SUBWAY_DATA['호선']=='06호선']
SUBWAY_DATA_07 = SUBWAY_DATA[SUBWAY_DATA['호선']=='07호선']
SUBWAY_DATA_08 = SUBWAY_DATA[SUBWAY_DATA['호선']=='08호선']
SUBWAY_DATA_09 = SUBWAY_DATA[SUBWAY_DATA['호선']=='09호선']
SUBWAY_DATA_k1 = SUBWAY_DATA[SUBWAY_DATA['호선']=='경의선']
SUBWAY_DATA_k2 = SUBWAY_DATA[SUBWAY_DATA['호선']=='경춘선']
SUBWAY_DATA_k3 = SUBWAY_DATA[SUBWAY_DATA['호선']=='김포도시철도']
SUBWAY_DATA_g = SUBWAY_DATA[SUBWAY_DATA['호선']=='공항철도']
SUBWAY_DATA_b = SUBWAY_DATA[SUBWAY_DATA['호선']=='분당선']
SUBWAY_DATA_s = SUBWAY_DATA[SUBWAY_DATA['호선']=='신분당선']
SUBWAY_DATA_u = SUBWAY_DATA[SUBWAY_DATA['호선']=='우이신설경전철']

# %%
#02. 지하철 시각화하기. 
map = folium.Map(location=[37.561, 126.986], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = SEOUL_GU,
    fill_color = 'snow')

for i in SUBWAY_DATA_01.index:
    folium.CircleMarker(
        [SUBWAY_DATA_01['위도'][i], SUBWAY_DATA_01['경도'][i]], 
        radius=10, color='#', fill_color='#0052A4', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[SUBWAY_DATA_01['위도'][i], SUBWAY_DATA_01['경도'][i]],
        radius = 5, color='#0052A4', tooltip=f"{SUBWAY_DATA_01.역명[i]}").add_to(map)
for i in SUBWAY_DATA_02.index:
    folium.CircleMarker(
        [SUBWAY_DATA_02['위도'][i], SUBWAY_DATA_02['경도'][i]], 
        radius=10, color='#', fill_color='#009D3E', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[SUBWAY_DATA_02['위도'][i], SUBWAY_DATA_02['경도'][i]],
        radius = 5, color='#009D3E', tooltip=f"{SUBWAY_DATA_02.역명[i]}").add_to(map)
for i in SUBWAY_DATA_03.index:
    folium.CircleMarker(
        [SUBWAY_DATA_03['위도'][i], SUBWAY_DATA_03['경도'][i]], 
        radius=10, color='#', fill_color='#EF7C1C', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[SUBWAY_DATA_03['위도'][i], SUBWAY_DATA_03['경도'][i]],
        radius = 5, color='#EF7C1C', tooltip=f"{SUBWAY_DATA_03.역명[i]}").add_to(map)
for i in SUBWAY_DATA_04.index:
    folium.CircleMarker(
        [SUBWAY_DATA_04['위도'][i], SUBWAY_DATA_04['경도'][i]], 
        radius=10, color='#', fill_color='#00A5DE', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[SUBWAY_DATA_04['위도'][i], SUBWAY_DATA_04['경도'][i]],
        radius = 5, color='#00A5DE', tooltip=f"{SUBWAY_DATA_04.역명[i]}").add_to(map)
for i in SUBWAY_DATA_05.index:
    folium.CircleMarker(
        [SUBWAY_DATA_05['위도'][i], SUBWAY_DATA_05['경도'][i]], 
        radius=10, color='#', fill_color='#996CAC', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[SUBWAY_DATA_05['위도'][i], SUBWAY_DATA_05['경도'][i]],
        radius = 5, color='#996CAC', tooltip=f"{SUBWAY_DATA_05.역명[i]}").add_to(map)
for i in SUBWAY_DATA_06.index:
    folium.CircleMarker(
        [SUBWAY_DATA_06['위도'][i], SUBWAY_DATA_06['경도'][i]], 
        radius=10, color='#', fill_color='#CD7C2F', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[SUBWAY_DATA_06['위도'][i], SUBWAY_DATA_06['경도'][i]],
        radius = 5, color='#CD7C2F',tooltip=f"{SUBWAY_DATA_06.역명[i]}").add_to(map)
for i in SUBWAY_DATA_07.index:
    folium.CircleMarker(
        [SUBWAY_DATA_07['위도'][i], SUBWAY_DATA_07['경도'][i]], 
        radius=10, color='#', fill_color='#747F00', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[SUBWAY_DATA_07['위도'][i], SUBWAY_DATA_07['경도'][i]],
        radius = 5, color='#747F00', tooltip=f"{SUBWAY_DATA_07.역명[i]}").add_to(map)
for i in SUBWAY_DATA_08.index:
    folium.CircleMarker(
        [SUBWAY_DATA_08['위도'][i], SUBWAY_DATA_08['경도'][i]], 
        radius=10, color='#', fill_color='#EA545D', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[SUBWAY_DATA_08['위도'][i], SUBWAY_DATA_08['경도'][i]],
        radius = 5, color='#EA545D', tooltip=f"{SUBWAY_DATA_08.역명[i]}").add_to(map)
for i in SUBWAY_DATA_09.index:
    folium.CircleMarker(
        [SUBWAY_DATA_09['위도'][i], SUBWAY_DATA_09['경도'][i]], 
        radius=10, color='#', fill_color='#BB8336', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[SUBWAY_DATA_09['위도'][i], SUBWAY_DATA_09['경도'][i]],
        radius = 5, color='#BB8336', tooltip=f"{SUBWAY_DATA_09.역명[i]}").add_to(map)
for i in SUBWAY_DATA_k1.index:
    folium.CircleMarker(
        [SUBWAY_DATA_k1['위도'][i], SUBWAY_DATA_k1['경도'][i]], 
        radius=10, color='#', fill_color='#77C4A3', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[SUBWAY_DATA_k1['위도'][i], SUBWAY_DATA_k1['경도'][i]],
        radius = 5, color='#77C4A3', tooltip=f"{SUBWAY_DATA_k1.역명[i]}").add_to(map)
for i in SUBWAY_DATA_k2.index:
    folium.CircleMarker(
        [SUBWAY_DATA_k2['위도'][i], SUBWAY_DATA_k2['경도'][i]], 
        radius=10, color='#', fill_color='#0C8E72', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[SUBWAY_DATA_k2['위도'][i], SUBWAY_DATA_k2['경도'][i]],
        radius = 5, color='#0C8E72', tooltip=f"{SUBWAY_DATA_k2.역명[i]}").add_to(map)
for i in SUBWAY_DATA_k3.index:
    folium.CircleMarker(
        [SUBWAY_DATA_k3['위도'][i], SUBWAY_DATA_k3['경도'][i]], 
        radius=10, color='#', fill_color='#A17800', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[SUBWAY_DATA_k3['위도'][i], SUBWAY_DATA_k3['경도'][i]],
        radius = 5, color='#A17800', tooltip=f"{SUBWAY_DATA_k3.역명[i]}").add_to(map)
for i in SUBWAY_DATA_g.index:
    folium.CircleMarker(
        [SUBWAY_DATA_g['위도'][i], SUBWAY_DATA_g['경도'][i]], 
        radius=10, color='#', fill_color='#0065B3', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[SUBWAY_DATA_g['위도'][i], SUBWAY_DATA_g['경도'][i]],
        radius = 5, color='#0065B3', tooltip=f"{SUBWAY_DATA_g.역명[i]}").add_to(map)
for i in SUBWAY_DATA_b.index:
    folium.CircleMarker(
        [SUBWAY_DATA_b['위도'][i], SUBWAY_DATA_b['경도'][i]], 
        radius=10, color='#', fill_color='#F5A200', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[SUBWAY_DATA_b['위도'][i], SUBWAY_DATA_b['경도'][i]],
        radius = 5, color='#F5A200',tooltip=f"{SUBWAY_DATA_b.역명[i]}").add_to(map)
for i in SUBWAY_DATA_s.index:
    folium.CircleMarker(
        [SUBWAY_DATA_s['위도'][i], SUBWAY_DATA_s['경도'][i]], 
        radius=10, color='#', fill_color='#D4003B', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[SUBWAY_DATA_s['위도'][i], SUBWAY_DATA_s['경도'][i]],
        radius = 5, color='#D4003B', tooltip=f"{SUBWAY_DATA_s.역명[i]}").add_to(map)
for i in SUBWAY_DATA_u.index:
    folium.CircleMarker(
        [SUBWAY_DATA_u['위도'][i], SUBWAY_DATA_u['경도'][i]], 
        radius=10, color='#', fill_color='#B7C452', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[SUBWAY_DATA_u['위도'][i], SUBWAY_DATA_u['경도'][i]],
        radius = 5, color='#B7C452', tooltip=f"{SUBWAY_DATA_u.역명[i]}").add_to(map)

map
# Out:
# C:\Users\CSH\miniconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# ...
