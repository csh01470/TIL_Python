# %%
#2021.10.18. SAT
#Team_SmokeFree

## EDA Dataset Correlation
#00. 패키지 호출하기. 
import warnings
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np 

#00-1. warning message ignore 
warnings.filterwarnings(action='ignore')

#00-2. 시각화 옵션 설정하기.  
sns.set(font_scale = 1)
# %matplotlib inline
#mpl.rcParams["axes.unicode_minus"] = False
plt.rcParams["font.family"] = 'D2Coding'

#01. 데이터셋 전처리하기. 
#(1) 데이터셋 불러오기. 
DATASET = pd.read_excel('../data/FINAL_DATASET_Dong.xlsx')

#(2) 필요 변수 추출하기. 
DATASET = DATASET[[
    '추정흡연유동인구',
    '사업체',
    '세대',
    '버스정류장',
    '지하철',
    '노래연습장',
    '당구장',
    '유흥주점',
    '관광극장',
    'PC방',
    '담배소매업',
    '금연구역_10m',
    '금연구역_50m',
    '금연구역_BOTH',
    '금연구역_ETC',
    '음식점_외식',
    '음식점_회식',
    '음식점_주점',
    '음식점_카페',
]]

#(3) 처리 결과 확인하기. 
DATASET
# Out:
#        사업체     세대  버스정류장  지하철  노래연습장  당구장  유흥주점  관광극장  PC방  담배소매업  금연구역_10m  \
# 0     2988   9816      0    0      0    0     0     0    0     54         0
# 1     1901  12370     61    5     30    5     0     0   16     47         0
# 2     3489  11905      0    0     87   16    41     0   36     75         2
# 3      993   5913      7    0     41    2     0     0   25     50        42
# 4    16661  16365    105    3     40   34    17     0    9    182        56
# ..     ...    ...    ...  ...    ...  ...   ...   ...  ...    ...       ...
# 419    418   4402     14    2      0    2     0     0    0     15         0
# 420    928   8445     19    0      3    2     0     0    2     27         0
# 421    929   7350      0    0      9    1     3     0    2     40         2
# 422   1221  11876     31    3      3    3     0     0    4     37         4
# 423   1557  14015     46    1      8   12     1     0   14     48         6
#
#      금연구역_50m  금연구역_BOTH  금연구역_ETC  음식점_외식  음식점_회식  음식점_주점  음식점_카페  \
# 0           0          0         3     113      12       0       1
# 1           0          0        58     158      25       0       3
# 2           4          0        46     404      51       3       9
# 3           5          0        42     150      73       0       1
# 4           1          0        13     761     143       0      15
# ..        ...        ...       ...     ...     ...     ...     ...
# 419         1          0         3      28       9       0       2
# 420         3          0         2     126      14       0       8
# 421         1          0         1     105      28       0       1
# 422         4          0        11      75      20       1       3
# 423         6          3        24     225      62       0       6
#
#         추정흡연유동인구
# 0    45866.69034
# 1    36505.53658
# 2    68093.91810
# 3    12796.84348
# 4    74178.65316
# ..           ...
# 419   9227.60194
# 420  16188.88646
# 421  25345.57588
# 422  22478.80922
# 423  41434.99582
#
# [424 rows x 19 columns]

# %%
#(4) 시각화 시행하기. 
corr = DATASET.corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(11, 9))

cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
            
plt.show()
